# %%
import _pickle as pickle

# %%
f = open('/work/relation_extraction/LSTM_seq_tree_model/data/testing_data/test_pathsv3', 'rb')
words_seq, deps_seq, pos_tags_seq, word_path1, word_path2, dep_path1, dep_path2, pos_tags_path1, pos_tags_path2, pos_path1, pos_path2, childs_path1, childs_path2 = pickle.load(f)
f.close()

# %%
for i in range(5497, 5507):
    print(words_seq[i])
    print(deps_seq[i])
    print(pos_tags_seq[i])
    print(word_path1[i])
    print(word_path2[i])
    print(dep_path1[i])
    print(dep_path2[i])
    print(pos_tags_path1[i])
    print(pos_tags_path2[i])
    print(pos_path1[i])
    print(pos_path2[i])
    print(childs_path1[i])
    print(childs_path2[i])
# Out:
# ['check', 'in', 'on', 'the', 'pentagon', 'for', 'more', 'and', 'more', 'on', 'this', 'tape', 'and', 'what', 'they', "'re", 'saying', 'down', 'in', 'washington', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# ['NN', 'IN', 'IN', 'DT', 'NN', 'IN', 'JJR', 'CC', 'RBR', 'IN', 'DT', 'NN', 'CC', 'WP', 'PRP', 'VBP', 'VBG', 'RP', 'IN', 'NN', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
# ['\n', 'FLOPPINGACES', '_', '20041114.1240.039', 'WEB', 'TEXT', '2004-11-14T12:40:00', 'al-Qaeda', '&', 'Nukes', 'Curt', '2004-11-14T12:40:00', 'Time', 'is', 'reporting', 'today', 'that', 'a', 'al-Qaeda', 'operative', 'was', 'captured', 'and', 'is', 'spitting', 'out', 'that', 'they', 'have', 'plans', 'in', 'the', 'work', 'to', 'smuggle', 'nukes', 'into', 'the', 'US', 'from', 'Mexico', ',', 'see', 'the', 'article', 'here', '.']
# [None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None]
# [None, 'NNP', 'SYM', 'CD', 'NN', 'NN', 'NN', 'NNP', 'CC', 'NNP', 'NNP', 'NNP', 'NNP', 'VBZ', 'VBG', 'NN', 'IN', 'DT', 'NNP', 'NN', 'VBD', 'VBN', 'CC', 'VBZ', 'VBG', 'RP', 'IN', 'PRP', 'VBP', 'NNS', 'IN', 'DT', 'NN', 'TO', 'VB', 'NNS', 'IN', 'DT', 'NNP', 'IN', 'NNP', ',', 'VBP', 'DT', 'NN', 'RB', '.']
# []
# []
# []
# []
# []
# []
# []
# []
# []
# []
